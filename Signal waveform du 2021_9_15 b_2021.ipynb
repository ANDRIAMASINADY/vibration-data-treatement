# %%
import pandas as pd
import matplotlib.pyplot as plt

# read csv file and stored it in vibration_data

vibration_data1 = pd.read_csv("C:/Users/Angeleco/Desktop/P4 [517]/ISO TEMPOREL Y [5235]/2021_9_15/ISO TEMPOREL Y.csv", sep = ";" , skiprows = 1)
# create graph waveform    
fig = plt.figure(0)
x1=vibration_data1["time[ms]"]
y1=vibration_data1[" amplitude[mm/s]"]
plt.plot(x1,y1)
plt.xlabel("Time[ms]")
plt.ylabel("Amplitude[mm/s]")
plt.title("Signal waveform du 2021_9_15 b_2021")
fig.savefig("Signal wave form.png")
